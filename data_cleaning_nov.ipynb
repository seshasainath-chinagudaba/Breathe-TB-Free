# %% [markdown]
# om sri sairam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data_2 = pd.read_csv("/content/drive/MyDrive/Project/data/cr_new.csv")
data_1 = pd.read_csv("/content/drive/MyDrive/Project/data/nr_new.csv")
# Out:
# <ipython-input-50-031f2efe8737>:1: DtypeWarning: Columns (35,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2 = pd.read_csv("/content/drive/MyDrive/Project/data/cr_new.csv")

# %%
# data_2 = pd.read_csv("/content/drive/MyDrive/cr_new.csv")
# data_1 = pd.read_csv("/content/drive/MyDrive/nr_new.csv")

# %%
data_1.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosingFacilityPHI_ID',
#        'DiagnosisDate', 'EnrollmentDate', 'EpisodeID', 'OldNikshayId',
#        'PatientId', 'Patient_Status', 'Age', 'Gender', 'Weight', 'Taluka',
#        'Town', 'Ward', 'Landmark', 'Pincode', 'Residential_State',
#        'Residential_District', 'Residential_TU', 'KeyPopulation',
#        'EnrollmentFacilityState', 'EnrollmentFacilityDistrict',
#        'EnrollmentFacilityTBU', 'EnrollmentFacilityPHI',
#        'EnrollmentFacilityPHIType', 'EnrollmentFacilityPHI_ID',
#        'UserID_Enrollment', 'HIV_Status', 'DiabetesStatus',
#        'basisOfDiagnosis_TestName', 'basisOfDiagnosis_LabSerialNo',
#        'basisOfDiagnosis_FinalInterpretation', 'Microbiologically_Confirmed',
#        'DateOf_TB_Treatment_Initiation', 'CurrentFacilityState',
# ...

# %%
# Print unique values in the 'Weight' column
print(data_1['Treatment_Outcome'].unique())
# Out:
# ['CURED' 'TREATMENT_COMPLETE' 'LOST_TO_FOLLOW_UP'
#  'UNTRACEABLE_INCORRECT_ADDRESS' 'TREATMENT_REGIMEN_CHANGED'
#  'UNTRACEABLE_MIGRATED' 'NOT_EVALUATED' 'PATIENT_REFUSED'
#  'WRONGLY_DIAGNOSED' 'DIED' 'TREATMENT_FAILURE' nan]

# %%
data_2.columns
# Out:
# Index(['DiagnosingFaciltyState', 'DiagnosingFaciltyDistrict',
#        'DiagnosingFaciltyTBU', 'DiagnosingFaciltyPHI',
#        'DiagnosingFaciltyPHIType', 'DiagnosingFaciltyPHI_ID',
#        'CurrentFacilityState', 'CurrentFacilityDistrict', 'CurrentFacilityTBU',
#        'CurrentFacilityPHI', 'CurrentFaciltyPHIType', 'CurrentFaciltyPHI_ID',
#        'PatientId', 'EpisodeID', 'Age', 'Gender', 'DiagnosisDate',
#        'DateOf_TB_Treatment_Initiation', 'Current Health Facility Sector',
#        'Diagnosis Health Facility Sector', 'SiteOfDisease', 'BasisOfDiagnosis',
#        'TypeOfCase', 'TreatmentStatus', 'HIV_Status', 'DateOf_HIVTesting',
#        'PIDNumber', 'DateOf_CPTDelivered', 'DateOf_ReferralToART',
#        'InitiatedOn_ART', 'DateOf_ARTInitiation', 'CD4Count', 'PreARTNumber',
#        'ARTNumber', 'DiabetesStatus', 'RBS', 'FBS', 'End_Of_IP',
#        'EndTreatment', 'InitiatedOn_AntiDiabetic',
#        'DateOf_AntiDiabeticInitiation', 'OtherComorbidity',
# ...

# %%
drop_columns_1=['DiagnosingFacilityPHI_ID', 'EnrollmentDate', 'Taluka',
       'Town', 'Ward', 'Landmark', 'Pincode','EnrollmentFacilityPHI_ID','basisOfDiagnosis_LabSerialNo',
       'basisOfDiagnosis_FinalInterpretation', 'Microbiologically_Confirmed',
       'CurrentFacilityPHI_ID', 'OldNikshayId',
        'EndOfIP_SM_DateOfReport', 'EndOfIP_LabID',
       'EndOfIP_FinalInterpretation', 'EndOfCP_SM_DateOfReport','PMDT_RegimenType',
       'EndOfCP_LabID', 'EndOfCP_FinalInterpretation', 'Latitude', 'Longitude',
       'Logged into TAS', 'Last TAS Login', 'TB Screening Tool Enrollment',
       'Patient Consent', 'TB patients provided support (Yes/No)',
       'Ni-kshay Mitra ID (who have provided the support)',
       'ABHA generated/seeded - Yes/No', 'ABHA ID - ABHA number',
       'ABHA Address']

# %%
df1 = data_1.drop(columns=drop_columns_1)

# %%
df1['EPSite'] = df1['EPSite'].fillna('unknown')
# Replace NaN values in 'DateOf_TB_Treatment_Initiation' with 'DiagnosisDate' only for rows where 'DateOf_TB_Treatment_Initiation' is NaN
df1.loc[df1['DateOf_TB_Treatment_Initiation'].isna(), 'DateOf_TB_Treatment_Initiation'] = df1['DiagnosisDate']

# %%
# Import pandas and datetime
import pandas as pd
from datetime import timedelta

# Convert 'DateOf_TB_Treatment_Initiation' to datetime if it's not already
df1['DateOf_TB_Treatment_Initiation'] = pd.to_datetime(df1['DateOf_TB_Treatment_Initiation'])

# Add 36 days to 'DateOf_TB_Treatment_Initiation' where 'Treatment_Outcome_Date' is NaN
df1.loc[df1['Treatment_Outcome_Date'].isna(), 'Treatment_Outcome_Date'] = df1['DateOf_TB_Treatment_Initiation'] + timedelta(days=36)

# %%
missing_percentage_1 = (df1.isnull().mean() * 100).round(2)
print(missing_percentage_1)
# Out:
# DiagnosingFacilityState           0.00
# DiagnosingFacilityDistrict        0.00
# DiagnosingFacilityTBU             0.00
# DiagnosingFacilityPHI             0.00
# DiagnosingFacilityPHIType         0.00
# DiagnosisDate                     0.00
# EpisodeID                         0.00
# PatientId                         0.00
# Patient_Status                    0.00
# Age                               0.00
# Gender                            0.00
# Weight                            4.79
# Residential_State                 0.00
# Residential_District              0.00
# Residential_TU                    2.94
# KeyPopulation                     0.00
# EnrollmentFacilityState           0.00
# EnrollmentFacilityDistrict        0.00
# EnrollmentFacilityTBU             0.00
# EnrollmentFacilityPHI             0.00
# EnrollmentFacilityPHIType         0.00
# UserID_Enrollment                 0.00
# HIV_Status                        0.00
# DiabetesStatus                    3.94
# ...

# %%
drop_columns_2=['DiagnosingFaciltyPHI_ID',
        'CurrentFaciltyPHI_ID',
      'DiagnosisDate',
       'DateOf_TB_Treatment_Initiation', 'DateOf_HIVTesting',
       'PIDNumber', 'DateOf_CPTDelivered', 'DateOf_ReferralToART',
       'InitiatedOn_ART', 'DateOf_ARTInitiation', 'PreARTNumber',
       'ARTNumber',  'End_Of_IP','DateOf_AntiDiabeticInitiation', 'OtherComorbidity',
        'EndTreatment', 'InitiatedOn_AntiDiabetic',
        'TobaccoType', 'LinkedForCessation',
       'StatusOf_TobaccoAtTreatmentEnd','CD4Count','FBS',

       'LinkedForDeaddiction',
       ]

# %%
df2 = data_2.drop(columns=drop_columns_2)

# %%
missing_percentage_2 = (df2.isnull().mean() * 100).round(2)
print(missing_percentage_2)
# Out:
# DiagnosingFaciltyState               0.04
# DiagnosingFaciltyDistrict            0.04
# DiagnosingFaciltyTBU                 0.04
# DiagnosingFaciltyPHI                 0.04
# DiagnosingFaciltyPHIType             0.04
# CurrentFacilityState                 0.00
# CurrentFacilityDistrict              0.00
# CurrentFacilityTBU                   0.00
# CurrentFacilityPHI                   0.00
# CurrentFaciltyPHIType                0.00
# PatientId                            0.00
# EpisodeID                            0.00
# Age                                  0.00
# Gender                               0.00
# Current Health Facility Sector       0.00
# Diagnosis Health Facility Sector     0.04
# SiteOfDisease                        3.53
# BasisOfDiagnosis                     3.24
# TypeOfCase                           0.00
# TreatmentStatus                      0.00
# HIV_Status                           0.00
# DiabetesStatus                       4.10
# ...

# %%
df1
# Out:
#        DiagnosingFacilityState DiagnosingFacilityDistrict  \
# 0                    KARNATAKA                 DAVANAGERE
# 1                    KARNATAKA                    RAICHUR
# 2                    KARNATAKA                      KOLAR
# 3                    KARNATAKA                    BELGAUM
# 4                    KARNATAKA                    BELLARY
# ...                        ...                        ...
# 153171               KARNATAKA                     TUMKUR
# 153172               KARNATAKA             BENGALURU CITY
# 153173               KARNATAKA                     TUMKUR
# 153174               KARNATAKA             BENGALURU CITY
# 153175               KARNATAKA             BENGALURU CITY
#
#        DiagnosingFacilityTBU                    DiagnosingFacilityPHI  \
# 0           DAVANAGERE URBAN                SIDDESH DIAGNOSTIC CENTER
# 1                SINDHANUR 1                           SINDHANUR -SDH
# ...

# %%
df2
# Out:
#        DiagnosingFaciltyState DiagnosingFaciltyDistrict DiagnosingFaciltyTBU  \
# 0                   KARNATAKA            BENGALURU CITY    HOSAHALLI TB UNIT
# 1                   KARNATAKA            BENGALURU CITY    HOSAHALLI TB UNIT
# 2                   KARNATAKA            BENGALURU CITY    HOSAHALLI TB UNIT
# 3                   KARNATAKA            BENGALURU CITY    HOSAHALLI TB UNIT
# 4                   KARNATAKA            BENGALURU CITY    HOSAHALLI TB UNIT
# ...                       ...                       ...                  ...
# 150947              KARNATAKA                    KOPPAL           GANGAVATHI
# 150948              KARNATAKA                    KOPPAL           GANGAVATHI
# 150949              KARNATAKA                    KOPPAL           GANGAVATHI
# 150950              KARNATAKA                    KOPPAL           GANGAVATHI
# 150951              KARNATAKA                    KOPPAL           GANGAVATHI
#
# ...

# %%
common_episode_ids = pd.merge(df1, df2, on='EpisodeID')['EpisodeID']
num_matching_episodes = len(common_episode_ids)
print(f"Number of matching episode IDs: {num_matching_episodes}")
# Out:
# Number of matching episode IDs: 148781

# %%
print("Columns in df1:", df1.columns)
print("Columns in df2:", df2.columns)
# Out:
# Columns in df1: Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosisDate', 'EpisodeID', 'PatientId',
#        'Patient_Status', 'Age', 'Gender', 'Weight', 'Residential_State',
#        'Residential_District', 'Residential_TU', 'KeyPopulation',
#        'EnrollmentFacilityState', 'EnrollmentFacilityDistrict',
#        'EnrollmentFacilityTBU', 'EnrollmentFacilityPHI',
#        'EnrollmentFacilityPHIType', 'UserID_Enrollment', 'HIV_Status',
#        'DiabetesStatus', 'basisOfDiagnosis_TestName',
#        'DateOf_TB_Treatment_Initiation', 'CurrentFacilityState',
#        'CurrentFacilityDistrict', 'CurrentFacilityTBU', 'CurrentFacilityPHI',
#        'CurrentFacilityPHIType', 'TypeOfCase', 'SiteOfDisease', 'EPSite',
#        'Treatment_Outcome', 'Treatment_Outcome_Date', 'BankDetailsAdded',
#        'FollowupDone_Count', 'ContactTracing_Done'],
#       dtype='object')
# ...

# %%
merged_df = pd.merge(df1, df2, left_on='EpisodeID', right_on='EpisodeID', how='inner')
merged_df
# Out:
#        DiagnosingFacilityState DiagnosingFacilityDistrict  \
# 0                    KARNATAKA                 DAVANAGERE
# 1                    KARNATAKA                    RAICHUR
# 2                    KARNATAKA                      KOLAR
# 3                    KARNATAKA                    BELGAUM
# 4                    KARNATAKA                    BELLARY
# ...                        ...                        ...
# 148776               KARNATAKA                     TUMKUR
# 148777               KARNATAKA             BENGALURU CITY
# 148778               KARNATAKA                     TUMKUR
# 148779               KARNATAKA             BENGALURU CITY
# 148780               KARNATAKA             BENGALURU CITY
#
#        DiagnosingFacilityTBU                    DiagnosingFacilityPHI  \
# 0           DAVANAGERE URBAN                SIDDESH DIAGNOSTIC CENTER
# 1                SINDHANUR 1                           SINDHANUR -SDH
# ...

# %%
merged_df.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosisDate', 'EpisodeID',
#        'PatientId_x', 'Patient_Status', 'Age_x', 'Gender_x', 'Weight',
#        'Residential_State', 'Residential_District', 'Residential_TU',
#        'KeyPopulation', 'EnrollmentFacilityState',
#        'EnrollmentFacilityDistrict', 'EnrollmentFacilityTBU',
#        'EnrollmentFacilityPHI', 'EnrollmentFacilityPHIType',
#        'UserID_Enrollment', 'HIV_Status_x', 'DiabetesStatus_x',
#        'basisOfDiagnosis_TestName', 'DateOf_TB_Treatment_Initiation',
#        'CurrentFacilityState_x', 'CurrentFacilityDistrict_x',
#        'CurrentFacilityTBU_x', 'CurrentFacilityPHI_x',
#        'CurrentFacilityPHIType', 'TypeOfCase_x', 'SiteOfDisease_x', 'EPSite',
#        'Treatment_Outcome', 'Treatment_Outcome_Date', 'BankDetailsAdded',
# ...

# %%
merged_df = pd.merge(df1, df2, left_on='EpisodeID', right_on='EpisodeID', how='inner')
common_columns = set(df1.columns).intersection(df2.columns)
for column in common_columns:
    if f"{column}_x" in merged_df.columns and f"{column}_y" in merged_df.columns:
        print(f"Common column: {column}, Corresponding columns in merged_df: {column}_x, {column}_y")
# Out:
# Common column: HIV_Status, Corresponding columns in merged_df: HIV_Status_x, HIV_Status_y
# Common column: CurrentFacilityPHI, Corresponding columns in merged_df: CurrentFacilityPHI_x, CurrentFacilityPHI_y
# Common column: CurrentFacilityState, Corresponding columns in merged_df: CurrentFacilityState_x, CurrentFacilityState_y
# Common column: CurrentFacilityTBU, Corresponding columns in merged_df: CurrentFacilityTBU_x, CurrentFacilityTBU_y
# Common column: PatientId, Corresponding columns in merged_df: PatientId_x, PatientId_y
# Common column: DiabetesStatus, Corresponding columns in merged_df: DiabetesStatus_x, DiabetesStatus_y
# Common column: CurrentFacilityDistrict, Corresponding columns in merged_df: CurrentFacilityDistrict_x, CurrentFacilityDistrict_y
# Common column: Age, Corresponding columns in merged_df: Age_x, Age_y
# Common column: SiteOfDisease, Corresponding columns in merged_df: SiteOfDisease_x, SiteOfDisease_y
# ...

# %%
merged_df = pd.merge(df1, df2, left_on='EpisodeID', right_on='EpisodeID', how='inner')
different_gender_rows = merged_df[merged_df['Gender_x'] != merged_df['Gender_y']]
print(different_gender_rows[['EpisodeID', 'Gender_x', 'Gender_y']])
# Out:
# Empty DataFrame
# Columns: [EpisodeID, Gender_x, Gender_y]
# Index: []

# %%
merged_df['SiteOfDisease_x'] = merged_df['SiteOfDisease_x'].fillna('unknown')
merged_df['SiteOfDisease_y'] = merged_df['SiteOfDisease_y'].fillna('unknown')
merged_df['DiabetesStatus_y'] = merged_df['DiabetesStatus_y'].fillna('unknown')
merged_df['DiabetesStatus_x'] = merged_df['DiabetesStatus_x'].fillna('unknown')

# %%
test=['Gender_y','HIV_Status_y','TypeOfCase_y','CurrentFacilityTBU_y','CurrentFacilityState_y','SiteOfDisease_y','DiabetesStatus_y','CurrentFacilityDistrict_y','Age_y','PatientId_y','CurrentFacilityPHI_y']

# %%
new_df = merged_df.drop(columns=test)

# %%
new_df.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosisDate', 'EpisodeID',
#        'PatientId_x', 'Patient_Status', 'Age_x', 'Gender_x', 'Weight',
#        'Residential_State', 'Residential_District', 'Residential_TU',
#        'KeyPopulation', 'EnrollmentFacilityState',
#        'EnrollmentFacilityDistrict', 'EnrollmentFacilityTBU',
#        'EnrollmentFacilityPHI', 'EnrollmentFacilityPHIType',
#        'UserID_Enrollment', 'HIV_Status_x', 'DiabetesStatus_x',
#        'basisOfDiagnosis_TestName', 'DateOf_TB_Treatment_Initiation',
#        'CurrentFacilityState_x', 'CurrentFacilityDistrict_x',
#        'CurrentFacilityTBU_x', 'CurrentFacilityPHI_x',
#        'CurrentFacilityPHIType', 'TypeOfCase_x', 'SiteOfDisease_x', 'EPSite',
#        'Treatment_Outcome', 'Treatment_Outcome_Date', 'BankDetailsAdded',
# ...

# %%
new_df.columns = [col.replace('_x', '') if '_x' in col else col for col in new_df.columns]
new_df.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosisDate', 'EpisodeID', 'PatientId',
#        'Patient_Status', 'Age', 'Gender', 'Weight', 'Residential_State',
#        'Residential_District', 'Residential_TU', 'KeyPopulation',
#        'EnrollmentFacilityState', 'EnrollmentFacilityDistrict',
#        'EnrollmentFacilityTBU', 'EnrollmentFacilityPHI',
#        'EnrollmentFacilityPHIType', 'UserID_Enrollment', 'HIV_Status',
#        'DiabetesStatus', 'basisOfDiagnosis_TestName',
#        'DateOf_TB_Treatment_Initiation', 'CurrentFacilityState',
#        'CurrentFacilityDistrict', 'CurrentFacilityTBU', 'CurrentFacilityPHI',
#        'CurrentFacilityPHIType', 'TypeOfCase', 'SiteOfDisease', 'EPSite',
#        'Treatment_Outcome', 'Treatment_Outcome_Date', 'BankDetailsAdded',
#        'FollowupDone_Count', 'ContactTracing_Done', 'DiagnosingFaciltyState',
# ...

# %%
# # Assuming 'df' is your DataFrame
# new_df.to_csv('/content/drive/MyDrive/data/club_df.csv', index=False)

# %%
new_df.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'DiagnosisDate', 'EpisodeID', 'PatientId',
#        'Patient_Status', 'Age', 'Gender', 'Weight', 'Residential_State',
#        'Residential_District', 'Residential_TU', 'KeyPopulation',
#        'EnrollmentFacilityState', 'EnrollmentFacilityDistrict',
#        'EnrollmentFacilityTBU', 'EnrollmentFacilityPHI',
#        'EnrollmentFacilityPHIType', 'UserID_Enrollment', 'HIV_Status',
#        'DiabetesStatus', 'basisOfDiagnosis_TestName',
#        'DateOf_TB_Treatment_Initiation', 'CurrentFacilityState',
#        'CurrentFacilityDistrict', 'CurrentFacilityTBU', 'CurrentFacilityPHI',
#        'CurrentFacilityPHIType', 'TypeOfCase', 'SiteOfDisease', 'EPSite',
#        'Treatment_Outcome', 'Treatment_Outcome_Date', 'BankDetailsAdded',
#        'FollowupDone_Count', 'ContactTracing_Done', 'DiagnosingFaciltyState',
# ...

# %%
new_df_df = pd.merge(df1, df2, left_on='EpisodeID', right_on='EpisodeID', how='inner')
different_gender_rows = new_df[merged_df['Patient_Status'] == new_df['TreatmentStatus']]
print(different_gender_rows[['EpisodeID', 'Patient_Status', 'TreatmentStatus']])
# Out:
#         EpisodeID              Patient_Status             TreatmentStatus
# 0        16638570  DIAGNOSED_OUTCOME_ASSIGNED  DIAGNOSED_OUTCOME_ASSIGNED
# 1        16641191  DIAGNOSED_OUTCOME_ASSIGNED  DIAGNOSED_OUTCOME_ASSIGNED
# 2        16641379  DIAGNOSED_OUTCOME_ASSIGNED  DIAGNOSED_OUTCOME_ASSIGNED
# 3        16643975  DIAGNOSED_OUTCOME_ASSIGNED  DIAGNOSED_OUTCOME_ASSIGNED
# 4        16644477  DIAGNOSED_OUTCOME_ASSIGNED  DIAGNOSED_OUTCOME_ASSIGNED
# ...           ...                         ...                         ...
# 148776   33413960      DIAGNOSED_ON_TREATMENT      DIAGNOSED_ON_TREATMENT
# 148777   33414246      DIAGNOSED_ON_TREATMENT      DIAGNOSED_ON_TREATMENT
# 148778   33414371      DIAGNOSED_ON_TREATMENT      DIAGNOSED_ON_TREATMENT
# 148779   33414521      DIAGNOSED_ON_TREATMENT      DIAGNOSED_ON_TREATMENT
# 148780   33414579      DIAGNOSED_ON_TREATMENT      DIAGNOSED_ON_TREATMENT
#
# [148780 rows x 3 columns]

# %%
new_df.loc[new_df['SiteOfDisease'] == 'Pulmonary', 'EPSite'] = 'unknown'
new_df.loc[new_df['SiteOfDisease'] == 'unknown', 'SiteOfDisease'] = 'Pulmonary'
new_df['State_of_TB'] = new_df['Treatment_Outcome'].apply(lambda x: 1 if x in ['TREATMENT_COMPLETE', 'CURED'] else 0)
new_df['TypeOfCase'] = new_df['TypeOfCase'].replace({'Retreatment: Recurrent': 'Retreatment','Retreatment: Others': 'Retreatment','Retreatment: Treatment after failure': 'Retreatment','Retreatment: Treatment after lost to follow up': 'Retreatment'})
new_df['CurrentTobaccoUser'] = new_df['CurrentTobaccoUser'].fillna('Unknown')
new_df['HO_AlcoholIntake'] = new_df['HO_AlcoholIntake'].fillna('Unknown')
new_df['Covid19Status'] = new_df['Covid19Status'].fillna('Unknown')
new_df.loc[new_df['Gender'].isin(['Male', 'Transgender']), 'PregnancyStatus'] = 'Not applicable'
new_df.loc[(new_df['Gender'] == 'Female') & new_df['PregnancyStatus'].isna(), 'PregnancyStatus'] = 'Unknown'
new_df['basisOfDiagnosis_TestName'] = new_df['basisOfDiagnosis_TestName'].replace('S Line LPA', 'SLLPA', regex=True)
new_df['basisOfDiagnosis_TestName'] = new_df['basisOfDiagnosis_TestName'].replace('F Line LPA', 'FLLPA', regex=True)
new_df['TypeOfCase'] = new_df['TypeOfCase'].replace({ 'Truenat(MTB)': 'Truenat(MTB)','Truenat(MTB-RIF)': 'Truenat(MTB-RIF)','Trunat(MTB)': 'Truenat(MTB)','Trunat(MTB-RIF)': 'Truenat(MTB-RIF)'})

# %%
missing_percentage_2 = (new_df.isnull().mean() * 100).round(2)
print(missing_percentage_2)
# Out:
# DiagnosingFacilityState              0.00
# DiagnosingFacilityDistrict           0.00
# DiagnosingFacilityTBU                0.00
# DiagnosingFacilityPHI                0.00
# DiagnosingFacilityPHIType            0.00
# DiagnosisDate                        0.00
# EpisodeID                            0.00
# PatientId                            0.00
# Patient_Status                       0.00
# Age                                  0.00
# Gender                               0.00
# Weight                               4.80
# Residential_State                    0.00
# Residential_District                 0.00
# Residential_TU                       2.82
# KeyPopulation                        0.00
# EnrollmentFacilityState              0.00
# EnrollmentFacilityDistrict           0.00
# EnrollmentFacilityTBU                0.00
# EnrollmentFacilityPHI                0.00
# EnrollmentFacilityPHIType            0.00
# UserID_Enrollment                    0.00
# ...

# %%
# Print unique values in the 'Weight' column
print(new_df['Weight'])
# Out:
# 0         60.0
# 1         48.0
# 2         47.0
# 3         45.0
# 4         39.0
#           ...
# 148776    48.0
# 148777    27.0
# 148778    58.0
# 148779    35.0
# 148780    75.0
# Name: Weight, Length: 148781, dtype: float64

# %%
# Print unique values in the 'Weight' column
print(new_df['Weight'].unique())
# Out:
# [ 60.  48.  47.  45.  39.  49.  30.  nan  81.  42.  73.   6.  35.  51.
#   33.  52.  43.  44.  62.  34.  50.  53.  31.  27.  54.  37.  67.  40.
#   46.  41.  57.  17.  75.  70.  65.  38.  61.   8.  55.  36.  10.  32.
#   56.  24.  28.  72.  63.  25.  66.  68.  59.  69.  64.  58.  26. 166.
#   85.  80.  22.  74.  19. 168.  29.  16.  79.  98.  12. 156.  84.  13.
#    7.  76. 170.  92.   5.  78.  86. 163. 174.  15.  77. 160.  71.  82.
#    3.  90. 100.  88.  18. 104.  83.  20.   4. 152.  95.  89.   9.   1.
#   21.  23.  14.  11. 167.  93.  97. 155.   2. 153.  94. 105.  96. 112.
#  101. 150.  91. 125.  87. 144. 102. 162. 113. 159. 139. 158. 103. 115.
#  108. 119. 165. 169. 142. 147. 109. 172. 135. 134. 164. 148.  99. 110.
#  154. 116. 145. 151. 175. 140. 106. 120. 146. 161. 107. 141. 117. 149.
#  157. 173. 183. 176. 111. 132. 178. 131. 137. 143. 124. 130. 189. 114.]

# %%
new_df['RBS'] = new_df['RBS'].astype(str)  # Convert to string to handle non-numeric values

# Use regular expression to extract numeric values
new_df['RBS'] = new_df['RBS'].str.extract('(\d+)', expand=False)

# Convert the column to numeric, which will convert the extracted numbers to numeric type
new_df['RBS'] = pd.to_numeric(new_df['RBS'], errors='coerce')

# Replace NaN values with 0
new_df['RBS'] = new_df['RBS'].fillna(0)

# %%
import numpy as np

# %%
new_df['Weight'] = new_df.groupby(['EpisodeID', 'Age'])['Weight'].transform(lambda x: x.fillna(x.mean()))

# %%
new_df['BasisOfDiagnosis'] = new_df['BasisOfDiagnosis'].combine_first(new_df['basisOfDiagnosis_TestName'])
new_df['BasisOfDiagnosis'] = new_df['BasisOfDiagnosis'].replace({'Gene Sequencing': 'Microbiologically confirmed','Cytopathology': 'Clinically diagnosed','Histopathology': 'Microbiologically confirmed'})

# %%
missing_percentage_2 = (new_df.isnull().mean() * 100).round(5)

# Display the result
print(missing_percentage_2)
# Out:
# DiagnosingFacilityState             0.00000
# DiagnosingFacilityDistrict          0.00000
# DiagnosingFacilityTBU               0.00000
# DiagnosingFacilityPHI               0.00000
# DiagnosingFacilityPHIType           0.00134
# DiagnosisDate                       0.00000
# EpisodeID                           0.00000
# PatientId                           0.00000
# Patient_Status                      0.00000
# Age                                 0.00000
# Gender                              0.00000
# Weight                              4.79564
# Residential_State                   0.00000
# Residential_District                0.00000
# Residential_TU                      2.82429
# KeyPopulation                       0.00000
# EnrollmentFacilityState             0.00000
# EnrollmentFacilityDistrict          0.00000
# EnrollmentFacilityTBU               0.00000
# EnrollmentFacilityPHI               0.00000
# EnrollmentFacilityPHIType           0.00000
# ...

# %%
drop_test=['CurrentFacilityState','DiagnosisDate','Residential_State', 'Residential_District','Residential_TU','DiagnosingFaciltyState','DiagnosingFaciltyDistrict','PatientId','EpisodeID','DiagnosingFaciltyTBU','DiagnosingFaciltyPHI',  'DiagnosingFaciltyPHIType','CurrentFaciltyPHIType','Treatment_Outcome', 'TreatmentStatus','EnrollmentFacilityState', 'EnrollmentFacilityDistrict', 'EnrollmentFacilityTBU','EnrollmentFacilityPHI', 'EnrollmentFacilityPHIType',]

# %%
clean_df = new_df.drop(columns=drop_test)

# %%
clean_df
# Out:
#        DiagnosingFacilityState DiagnosingFacilityDistrict  \
# 0                    KARNATAKA                 DAVANAGERE
# 1                    KARNATAKA                    RAICHUR
# 2                    KARNATAKA                      KOLAR
# 3                    KARNATAKA                    BELGAUM
# 4                    KARNATAKA                    BELLARY
# ...                        ...                        ...
# 148776               KARNATAKA                     TUMKUR
# 148777               KARNATAKA             BENGALURU CITY
# 148778               KARNATAKA                     TUMKUR
# 148779               KARNATAKA             BENGALURU CITY
# 148780               KARNATAKA             BENGALURU CITY
#
#        DiagnosingFacilityTBU                    DiagnosingFacilityPHI  \
# 0           DAVANAGERE URBAN                SIDDESH DIAGNOSTIC CENTER
# 1                SINDHANUR 1                           SINDHANUR -SDH
# ...

# %%
missing_percentage_2 = (clean_df.isnull().mean() * 100).round(5)

# Display the result
print(missing_percentage_2)
# Out:
# DiagnosingFacilityState             0.00000
# DiagnosingFacilityDistrict          0.00000
# DiagnosingFacilityTBU               0.00000
# DiagnosingFacilityPHI               0.00000
# DiagnosingFacilityPHIType           0.00134
# Patient_Status                      0.00000
# Age                                 0.00000
# Gender                              0.00000
# Weight                              4.79564
# KeyPopulation                       0.00000
# UserID_Enrollment                   0.00000
# HIV_Status                          0.00000
# DiabetesStatus                      0.00000
# basisOfDiagnosis_TestName           0.00000
# DateOf_TB_Treatment_Initiation      0.00000
# CurrentFacilityDistrict             0.00000
# CurrentFacilityTBU                  0.00000
# CurrentFacilityPHI                  0.00000
# CurrentFacilityPHIType              0.00000
# TypeOfCase                          0.00000
# SiteOfDisease                       0.00000
# ...

# %%
clean_df.columns
# Out:
# Index(['DiagnosingFacilityState', 'DiagnosingFacilityDistrict',
#        'DiagnosingFacilityTBU', 'DiagnosingFacilityPHI',
#        'DiagnosingFacilityPHIType', 'Patient_Status', 'Age', 'Gender',
#        'Weight', 'KeyPopulation', 'UserID_Enrollment', 'HIV_Status',
#        'DiabetesStatus', 'basisOfDiagnosis_TestName',
#        'DateOf_TB_Treatment_Initiation', 'CurrentFacilityDistrict',
#        'CurrentFacilityTBU', 'CurrentFacilityPHI', 'CurrentFacilityPHIType',
#        'TypeOfCase', 'SiteOfDisease', 'EPSite', 'Treatment_Outcome_Date',
#        'BankDetailsAdded', 'FollowupDone_Count', 'ContactTracing_Done',
#        'Current Health Facility Sector', 'Diagnosis Health Facility Sector',
#        'BasisOfDiagnosis', 'RBS', 'CurrentTobaccoUser', 'HO_AlcoholIntake',
#        'Covid19Status', 'PregnancyStatus', 'State_of_TB'],
#       dtype='object')

# %%
clean_df.to_csv('/content/drive/MyDrive/Project/data/clean_df.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= clean_df

# Exploratory Data Analysis (EDA)
# Summary statistics
summary_stats = df.describe()

# Missing values
missing_values = df.isnull().sum()

# Correlation matrix
correlation_matrix = df.corr()

# Demographics-related statistics
positive_class_count = df[df['Patient_Status'] == 'Positive'].shape[0]
negative_class_count = df[df['Patient_Status'] == 'Negative'].shape[0]

gender_counts = df['Gender'].value_counts()

new_count = df[df['TypeOfCase'] == 'New'].shape[0]
retreatment_count = df[df['TypeOfCase'] == 'Retreatment'].shape[0]

# Visualizations
# Gender distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# Weight distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Weight'], bins=20, kde=True)
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.show()

# Pairplot for selected columns
selected_columns = ['Age', 'Weight', 'FollowupDone_Count', 'RBS']
sns.pairplot(df[selected_columns])
plt.suptitle('Pairplot of Selected Columns', y=1.02)
plt.show()

# Print the results
print('Exploratory Data Analysis (EDA):')
print('\nSummary Statistics:')
print(summary_stats)
print('\nMissing Values:')
print(missing_values)
print('\nCorrelation Matrix:')
print(correlation_matrix)

print('\nDemographics-related Statistics:')
print(f'Positive class count: {positive_class_count}')
print(f'Negative class count: {negative_class_count}')
print('\nGender-wise counts:')
print(gender_counts)
print('\nNew vs. Retreatment counts:')
print(f'New cases count: {new_count}')
print(f'Retreatment cases count: {retreatment_count}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-53e63ddeca11> in <cell line: 15>()
#      13
#      14 # Correlation matrix
# ---> 15 correlation_matrix = df.corr()
#      16
#      17 # Demographics-related statistics
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %%
import pandas as pd

# Load the data into a pandas DataFrame
df = clean_df

# Exploratory Data Analysis (EDA)
# Summary statistics
summary_stats = df.describe()

# Missing values
missing_values = df.isnull().sum()

# Correlation matrix
correlation_matrix = df.corr()

# Demographics-related statistics
positive_class_count = df[df['Patient_Status'] == 'Positive'].shape[0]
negative_class_count = df[df['Patient_Status'] == 'Negative'].shape[0]

gender_counts = df['Gender'].value_counts()

new_count = df[df['TypeOfCase'] == 'New'].shape[0]
retreatment_count = df[df['TypeOfCase'] == 'Retreatment'].shape[0]

# Print the results
print('Exploratory Data Analysis (EDA):')
print('\nSummary Statistics:')
print(summary_stats)
print('\nMissing Values:')
print(missing_values)
print('\nCorrelation Matrix:')
print(correlation_matrix)

print('\nDemographics-related Statistics:')
print(f'Positive class count: {positive_class_count}')
print(f'Negative class count: {negative_class_count}')
print('\nGender-wise counts:')
print(gender_counts)
print('\nNew vs. Retreatment counts:')
print(f'New cases count: {new_count}')
print(f'Retreatment cases count: {retreatment_count}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-bc6d11bedde3> in <cell line: 14>()
#      12
#      13 # Correlation matrix
# ---> 14 correlation_matrix = df.corr()
#      15
#      16 # Demographics-related statistics
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %%
print('Summary Statistics:')
print('\nAge:')
print(df['Age'].describe())
print('\nWeight:')
print(df['Weight'].describe())
print('\nFollowupDone_Count:')
print(df['FollowupDone_Count'].describe())
print('\nRBS:')
print(df['RBS'].describe())
print('\nState_of_TB:')
print(df['State_of_TB'].describe())

print('\nMissing Values:')
print(df.isnull().sum())

print('\nCorrelation Matrix:')
print(df.corr())

print('\nDemographics-related Statistics:')
print(f'{"-"*40}\n{"Positive class count":<30}{positive_class_count}')
print(f'{"Negative class count":<30}{negative_class_count}\n{"-"*40}')
print('\nGender-wise counts:')
print(gender_counts)
print(f'{"-"*40}\n{"New cases count":<30}{new_count}')
print(f'{"Retreatment cases count":<30}{retreatment_count}\n{"-"*40}')
# Out:
# Summary Statistics:
#
# Age:
# count    148781.000000
# mean         41.655951
# std          17.685757
# min           0.000000
# 25%          28.000000
# 50%          41.000000
# 75%          55.000000
# max          99.000000
# Name: Age, dtype: float64
#
# Weight:
# count    141646.000000
# mean         46.737430
# std          14.200618
# min           1.000000
# 25%          39.000000
# 50%          45.000000
# 75%          54.000000
# max         189.000000
# Name: Weight, dtype: float64
#
# FollowupDone_Count:
# count    148781.000000
# mean          0.517069
# std           2.108474
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          44.000000
# Name: FollowupDone_Count, dtype: float64
#
# RBS:
# count    148781.000000
# mean        112.440076
# std         190.669571
# min           0.000000
# 25%          89.000000
# 50%         103.000000
# 75%         123.000000
# max       64699.000000
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the data into a pandas DataFrame
df = clean_df

# Data Preprocessing
# Handle missing values
df.fillna(df.median(), inplace=True)  # Example: Impute missing values with median

# Convert categorical variables using one-hot encoding
categorical_columns = ['Gender', 'TypeOfCase']  # Add more as needed
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_columns),
        ('cat', OneHotEncoder(), categorical_columns)
    ])

# Demographics-related statistics
positive_class_count = df['Patient_Status'].eq('Positive').sum()
negative_class_count = df['Patient_Status'].eq('Negative').sum()

gender_counts = df['Gender'].value_counts()

new_count = df['TypeOfCase'].eq('New').sum()
retreatment_count = df['TypeOfCase'].eq('Retreatment').sum()

# Print the results
print('Demographics-related Statistics:')
print(f'Positive class count: {positive_class_count}')
print(f'Negative class count: {negative_class_count}')
print('\nGender-wise counts:')
print(gender_counts)
print('\nNew vs. Retreatment counts:')
print(f'New cases count: {new_count}')
print(f'Retreatment cases count: {retreatment_count}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     785         try:
# --> 786             values = values.astype("f8")
#     787         except ValueError as err:
#
# ValueError: could not convert string to float: 'KARNATAKA'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-68d6068bf79a> in <cell line: 11>()
#       9 # Data Preprocessing
#      10 # Handle missing values
# ---> 11 df.fillna(df.median(), inplace=True)  # Example: Impute missing values with median
#      12
#      13 # Convert categorical variables using one-hot encoding
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the data into a pandas DataFrame
df

# Data Preprocessing
# Handle missing values
df.fillna(df.median(), inplace=True)  # Example: Impute missing values with median

# Convert categorical variables using one-hot encoding
categorical_columns = ['Gender', 'TypeOfCase']  # Add more as needed
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_columns),
        ('cat', OneHotEncoder(), categorical_columns)
    ])

# Apply preprocessing
X = preprocessor.fit_transform(df.drop(columns=['Patient_Status']))

# Demographics-related statistics
positive_class_count = df['Patient_Status'].eq('Positive').sum()
negative_class_count = df['Patient_Status'].eq('Negative').sum()

gender_counts = df['Gender'].value_counts()

new_count = df['TypeOfCase'].eq('New').sum()
retreatment_count = df['TypeOfCase'].eq('Retreatment').sum()

# Additional statistics for other columns as needed
# ...

# Print the results
print('Demographics-related Statistics:')
print(f'Positive class count: {positive_class_count}')
print(f'Negative class count: {negative_class_count}')
print('\nGender-wise counts:')
print(gender_counts)
print('\nNew vs. Retreatment counts:')
print(f'New cases count: {new_count}')
print(f'Retreatment cases count: {retreatment_count}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     785         try:
# --> 786             values = values.astype("f8")
#     787         except ValueError as err:
#
# ValueError: could not convert string to float: 'KARNATAKA'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-a6050e75cd49> in <cell line: 11>()
#       9 # Data Preprocessing
#      10 # Handle missing values
# ---> 11 df.fillna(df.median(), inplace=True)  # Example: Impute missing values with median
#      12
#      13 # Convert categorical variables using one-hot encoding
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the data into a pandas DataFrame
df

# Data Preprocessing
# Handle missing values
df.fillna(df.median(), inplace=True)  # Example: Impute missing values with median

# Convert categorical variables using one-hot encoding
categorical_columns = ['Gender', 'TypeOfCase']  # Add more as needed
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_columns),
        ('cat', OneHotEncoder(), categorical_columns)
    ])

# Apply preprocessing
X = preprocessor.fit_transform(df.drop(columns=['Patient_Status']))

# Demographics-related statistics based on State_of_TB
positive_class_count = df['State_of_TB'].eq(1).sum()
negative_class_count = df['State_of_TB'].eq(0).sum()

gender_counts = df['Gender'].value_counts()

new_count = df['TypeOfCase'].eq('New').sum()
retreatment_count = df['TypeOfCase'].eq('Retreatment').sum()

# Additional statistics for other columns as needed
# ...

# Print the results in a summary-like format
print('Demographics-related Statistics:')
print(f'{"-"*40}\n{"Positive class count":<30}{positive_class_count}')
print(f'{"Negative class count":<30}{negative_class_count}\n{"-"*40}')
print('\nGender-wise counts:')
print(gender_counts)
print(f'{"-"*40}\n{"New cases count":<30}{new_count}')
print(f'{"Retreatment cases count":<30}{retreatment_count}\n{"-"*40}')
